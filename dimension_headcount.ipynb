# %%
import pandas as pd
import os

# Hiển thị đủ số dòng và số cột mong muốn
pd.set_option("display.max_rows", 100)   # tối đa số dòng hiển thị
pd.set_option("display.max_columns", None)  # hiện tất cả các cột
pd.set_option("display.width", None)   # không giới hạn độ rộng

# %%
# --- 1. Đọc dữ liệu từ file master ---
master_path = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Headcount\HC Master Database - 2025.xlsx"

# Đọc sheet "Active"
df = pd.read_excel(master_path, sheet_name="Active")

# --- 2. Chỉ giữ lại các cột cần thiết ---
cols_needed = ["Site", "IEX ID", "Employee Name", "LOB", "Supervisor Name", "Email Id"]
df = df[cols_needed]

# --- 3. Xuất ra file Excel mới ---
output_path = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Vu\unscheduled-agent\dimension-headcount.xlsx"

# Nếu file đã tồn tại thì xoá trước khi ghi lại
if os.path.exists(output_path):
    os.remove(output_path)

df.to_excel(output_path, index=False)

print("✅ File dimension-headcount.xlsx đã được tạo tại:")
print(output_path)

# Xem thử 50 dòng đầu tiên
df[df["Employee Name"]=="BUI BA DUONG"]
# Out:
# c:\Users\huuchinh.nguyen\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Cell T178 is marked as a date but the serial value 102029874 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\huuchinh.nguyen\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Cell T179 is marked as a date but the serial value 103117188 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\huuchinh.nguyen\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Cell T180 is marked as a date but the serial value 102029874 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# ...
